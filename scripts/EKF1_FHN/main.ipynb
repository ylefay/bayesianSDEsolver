# %%
import jax
import jax.numpy as jnp
import numpy as np
import matplotlib.pyplot as plt



solver_name = "EKF1_2"
problem_name = "FHN"
prefix = f"{solver_name}_{problem_name}"
folder = "./"

N = 128
delta = 1 / N
fineN = int(N ** 1.0)
T = 1
Ndeltas = T / delta
no_samples = 2

pn_sols = jnp.load(f'{folder}/{prefix}_pathwise_sols_{N}_1.npy')
fine_em = jnp.load(f'{folder}/{prefix}_pathwise_sols2_{N}_{fineN}.npy')

# %%
plt.plot(pn_sols[0,:,0])
plt.plot(fine_em[0,:,0])

# %%
fine_em.shape
# Out:
# (10, 129, 2)

# %%
pn_sols.shape
# Out:
# (10, 129, 2)

# %%
fine_em[0,:,0]
# Out:
# Array([ 0.        , -0.00180589, -0.00841392, -0.01517498, -0.02178963,
#        -0.03180378, -0.04115045, -0.05128774, -0.05944145, -0.06783097,
#        -0.07431664, -0.07779787, -0.07843211, -0.07938772, -0.08240626,
#        -0.08602696, -0.08894277, -0.09121952, -0.09518547, -0.09757337,
#        -0.09821989, -0.09778   , -0.09636667, -0.09623732, -0.09506012,
#        -0.09379583, -0.09339663, -0.09750021, -0.0997835 , -0.10185745,
#        -0.10333868, -0.10621059, -0.11006366, -0.11263859, -0.11515707,
#        -0.12021273, -0.12258669, -0.12268053, -0.12126034, -0.11749373,
#        -0.1114838 , -0.10578891, -0.10088038, -0.09571109, -0.09139595,
#        -0.08629633, -0.08143278, -0.07381912, -0.06424554, -0.0556152 ,
#        -0.04913018, -0.0429991 , -0.03691517, -0.03275516, -0.03062844,
#        -0.03043571, -0.02911917, -0.03027839, -0.03174714, -0.03326875,
#        -0.03723704, -0.04197881, -0.05099685, -0.06328552, -0.0775944 ,
#        -0.0945842 , -0.11636303, -0.13899949, -0.16318992, -0.19059074,
#        -0.22046724, -0.24805075, -0.2757207 , -0.3008759 , -0.32657182,
#        -0.3548971 , -0.38564453, -0.41801435, -0.4506656 , -0.4838987 ,
#        -0.5183801 , -0.55489504, -0.5899034 , -0.623813  , -0.65801626,
#        -0.6929052 , -0.7260516 , -0.75700295, -0.7792665 , -0.7987057 ,
#        -0.81551087, -0.8263505 , -0.8354311 , -0.84317225, -0.85104644,
#        -0.85717326, -0.8638942 , -0.8712244 , -0.87713325, -0.881084  ,
#        -0.8852296 , -0.889107  , -0.8915517 , -0.89101964, -0.890724  ,
#        -0.8918952 , -0.89308196, -0.8931032 , -0.8922466 , -0.8924058 ,
#        -0.8934508 , -0.89416265, -0.89203763, -0.8908053 , -0.89040446,
#        -0.8894569 , -0.8908126 , -0.8914164 , -0.8889066 , -0.8850164 ,
#        -0.8834848 , -0.88498104, -0.8866773 , -0.88826275, -0.8886343 ,
#        -0.8914172 , -0.89282036, -0.8936307 , -0.89533037], dtype=float32)
